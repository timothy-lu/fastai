# %%
#hide
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()

# %%
#hide
from fastbook import *
from fastai.vision.all import *
from fastai.vision.widgets import *
import fastai

# %% [markdown]
# # From Model to Production

# %% [markdown]
# ## The Practice of Deep Learning

# %% [markdown]
# ### Starting Your Project

# %% [markdown]
# ### The State of Deep Learning

# %% [markdown]
# #### Computer vision

# %% [markdown]
# #### Text (natural language processing)

# %% [markdown]
# #### Combining text and images

# %% [markdown]
# #### Tabular data

# %% [markdown]
# #### Recommendation systems

# %% [markdown]
# #### Other data types

# %% [markdown]
# ### The Drivetrain Approach

# %% [markdown]
# ## Gathering Data

# %% [markdown]
# # clean
# To download images with Bing Image Search, sign up at [Microsoft Azure](https://azure.microsoft.com/en-us/services/cognitive-services/bing-web-search-api/) for a free account. You will be given a key, which you can copy and enter in a cell as follows (replacing 'XXX' with your key and executing it):

# %%
import os
key = os.environ.get('AZURE_SEARCH_KEY', '7bc7239ed586439b928d1121084a42da')

# %%
#search_images_bing

# %%
#results = search_images_bing(key, 'roadhog overwatch')
#ims = results.attrgot('contentUrl')
#len(ims)

# %%
#hide
#ims = ['http://3.bp.blogspot.com/-S1scRCkI3vY/UHzV2kucsPI/AAAAAAAAA-k/YQ5UzHEm9Ss/s1600/Grizzly%2BBear%2BWildlife.jpg']

# %%
#dest = 'images/grizzly.jpg'
#download_url(ims[0], dest)

# %%
#im = Image.open(dest)
#im.to_thumb(128,128)

# %%
overwatch_champs = 'roadhog','mccree','wrecking ball'
path = Path('overwatch')

# %%
#league_of_legends = 'characters', 'champions'
#path1 = Path('generalleague')
#can NOT use underscore in folder name or else folder does not populate with images on API call

# %%
if not path.exists():
    path.mkdir()
    for o in overwatch_champs:
        dest = (path/o)
        dest.mkdir(exist_ok=True)
        results = search_images_bing(key, f'{o} overwatch')
        download_images(dest, urls=results.attrgot('contentUrl'))

# %%
#if not path1.exists():
    #path1.mkdir()
    #for o in league_of_legends:
        #dest = (path1/o)
        #dest.mkdir(exist_ok=True)
        #results = search_images_bing(key, f'{o} league of legends')
        #download_images(dest, urls=results.attrgot('contentUrl'))

# %%
fns = get_image_files(path)
fns
# Out:
# (#411) [Path('overwatch/roadhog/00000047.jpg'),Path('overwatch/roadhog/00000055.jpg'),Path('overwatch/roadhog/00000064.png'),Path('overwatch/roadhog/00000000.png'),Path('overwatch/roadhog/00000107.jpg'),Path('overwatch/roadhog/00000036.jpg'),Path('overwatch/roadhog/00000030.jpg'),Path('overwatch/roadhog/00000148.jpg'),Path('overwatch/roadhog/00000110.jpg'),Path('overwatch/roadhog/00000029.jpg')...]

# %%
failed = verify_images(fns)
failed
# Out:
# (#0) []

# %%
failed.map(Path.unlink);

# %% [markdown]
# ### Sidebar: Getting Help in Jupyter Notebooks

# %% [markdown]
# ### End sidebar

# %% [markdown]
# ## From Data to DataLoaders

# %%
#Fix construction of DataBlock into multicategory
#Currently the dimensions of the tensors do not align. Can NOT do cnn_learner with incorrect dimensions
#Need to properly construct a dataframe to provide multi category labels
#file names currently only provide single category information
def get_y(o): return [parent_label(o)]

dblock = DataBlock(
    blocks=(ImageBlock, MultiCategoryBlock), 
    get_items=get_image_files, 
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=get_y,
    item_tfms=RandomResizedCrop(224, min_scale=0.5))

# %%
dls = dblock.dataloaders(path)

# %%
dls.valid.show_batch(max_n=4, nrows=1)

# %%
#league = league.new(item_tfms=Resize(128, ResizeMethod.Squish))
#dls = league.dataloaders(path)
#dls.valid.show_batch(max_n=4, nrows=1)

# %%
#league = league.new(item_tfms=Resize(128, ResizeMethod.Pad, pad_mode='zeros'))
#dls = league.dataloaders(path)
#dls.valid.show_batch(max_n=4, nrows=1)

# %%
#league = league.new(item_tfms=RandomResizedCrop(128, min_scale=0.3))
#dls = league.dataloaders(path)
#dls.train.show_batch(max_n=4, nrows=1, unique=True)

# %% [markdown]
# # Data Augmentation

# %%
#league = league.new(item_tfms=Resize(128), batch_tfms=aug_transforms(mult=2))
#dls = league.dataloaders(path)
#dls.train.show_batch(max_n=8, nrows=2, unique=True)

# %% [markdown]
# ## Training Your Model, and Using It to Clean Your Data

# %%
#league = league.new(
    #item_tfms=RandomResizedCrop(224, min_scale=0.5),
    #batch_tfms=aug_transforms())
#dls = league.dataloaders(path)

# %%
learn = cnn_learner(dls, resnet18, metrics=partial(accuracy_multi,thresh=0.95), loss_func=BCEWithLogitsLossFlat(thresh=0.5))
#make sure that datablock is correctly constructed or else BinaryCrossEntropy will throw error tensor wrong dimensions
#lr_min, lr_steep = learn.lr_find()
#print(f"Minimum/10: {lr_min:.2e}, steepest point: {lr_steep:.2e}")
#learn.fine_tune(3, base_lr=1e-3, freeze_epochs=4)
learn.lr_find()
# Out:
# SuggestedLRs(valley=0.001737800776027143)

# %%
learn.loss_func
# Out:
# FlattenedLoss of BCEWithLogitsLoss()

# %%
lr=1e-3
learn.fit_one_cycle(5, lr)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy_multi</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.944579</td>
#       <td>0.695602</td>
#       <td>0.699187</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.743819</td>
#       <td>0.287507</td>
#       <td>0.861789</td>
#       <td>00:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.591401</td>
#       <td>0.165389</td>
#       <td>0.918699</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.495144</td>
#       <td>0.141574</td>
#       <td>0.951219</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.424059</td>
#       <td>0.138870</td>
#       <td>0.947155</td>
#       <td>00:09</td>
#     </tr>
#   </tbody>
# </table>

# %%
#interp = ClassificationInterpretation.from_learner(learn)
#interp.plot_confusion_matrix()
#confusion matrix doesn't work for multiclassification?

# %%
interp.plot_top_losses(4, nrows=1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>target</th>
#       <th>predicted</th>
#       <th>probabilities</th>
#       <th>loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>wrecking ball</td>
#       <td>mccree</td>
#       <td>TensorBase([0.9517, 0.0152, 0.1949])</td>
#       <td>1.5602234601974487</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>roadhog</td>
#       <td>wrecking ball</td>
#       <td>TensorBase([0.0669, 0.1227, 0.8728])</td>
#       <td>1.4097760915756226</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>wrecking ball</td>
#       <td>roadhog</td>
#       <td>TensorBase([0.0861, 0.6141, 0.3483])</td>
#       <td>0.6989889144897461</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>roadhog</td>
#       <td>roadhog;wrecking ball</td>
#       <td>TensorBase([0.0242, 0.9886, 0.8684])</td>
#       <td>0.6880089640617371</td>
# ...

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py:976: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# ...

# %%
#hide
for idx in cleaner.delete(): cleaner.fns[idx].unlink()
for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %% [markdown]
# ## Turning Your Model into an Online Application

# %% [markdown]
# ### Using the Model for Inference

# %%
learn.export()

# %%
path = Path()
path.ls(file_exts='.pkl')
# Out:
# (#1) [Path('export.pkl')]

# %%
learn_inf = load_learner(path/'export.pkl')

# %%
learn_inf.predict('images/grizzly.jpg')
# Out:
# ((#1) ['wrecking ball'],
#  TensorBase([False, False,  True]),
#  TensorBase([0.0216, 0.0112, 0.9337]))

# %%
learn_inf.dls.vocab
# Out:
# ['mccree', 'roadhog', 'wrecking ball']

# %%
img = PILImage.create('pink.png')
img
# Out:
# /opt/conda/lib/python3.7/site-packages/PIL/Image.py:976: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   "Palette images with Transparency expressed in bytes should be "
# PILImage mode=RGB size=1920x1080

# %%
learn_inf.predict(img)
# Out:
# ((#1) ['mccree'],
#  TensorBase([ True, False, False]),
#  TensorBase([0.9013, 0.0890, 0.3210]))

# %% [markdown]
# ### Creating a Notebook App from the Model

# %%
btn_upload = widgets.FileUpload()
btn_upload
# Out:
# FileUpload(value={}, description='Upload')

# %%
#hide
# For the book, we can't actually click an upload button, so we fake it
btn_upload = SimpleNamespace(data = ['images/grizzly.jpg'])

# %%
img = PILImage.create(btn_upload.data[-1])

# %%
out_pl = widgets.Output()
out_pl.clear_output()
with out_pl: display(img.to_thumb(128,128))
out_pl
# Out:
# Output()

# %%
pred,pred_idx,probs = learn_inf.predict(img)

# %%
lbl_pred = widgets.Label()
lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
lbl_pred
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_48/1347121715.py in <module>
#       1 lbl_pred = widgets.Label()
# ----> 2 lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'
#       3 lbl_pred
#
# /opt/conda/lib/python3.7/site-packages/torch/_tensor.py in __format__(self, format_spec)
#     567     def __format__(self, format_spec):
#     568         if has_torch_function_unary(self):
# --> 569             return handle_torch_function(Tensor.__format__, (self,), self, format_spec)
#     570         if self.dim() == 0:
#     571             return self.item().__format__(format_spec)
#
# /opt/conda/lib/python3.7/site-packages/torch/overrides.py in handle_torch_function(public_api, relevant_args, *args, **kwargs)
#    1353         # Use `public_api` instead of `implementation` so __torch_function__
# ...

# %%
btn_run = widgets.Button(description='Classify')
btn_run

# %%
def on_click_classify(change):
    img = PILImage.create(btn_upload.data[-1])
    out_pl.clear_output()
    with out_pl: display(img.to_thumb(128,128))
    pred,pred_idx,probs = learn_inf.predict(img)
    lbl_pred.value = f'Prediction: {pred}; Probability: {probs[pred_idx]:.04f}'

btn_run.on_click(on_click_classify)

# %%
#hide
#Putting back btn_upload to a widget for next cell
btn_upload = widgets.FileUpload()

# %%
VBox([widgets.Label('Select your bear!'), 
      btn_upload, btn_run, out_pl, lbl_pred])

# %% [markdown]
# ### Turning Your Notebook into a Real App

# %%
#hide
# !pip install voila
# !jupyter serverextension enable --sys-prefix voila

# %% [markdown]
# ### Deploying your app

# %% [markdown]
# ## How to Avoid Disaster

# %% [markdown]
# ### Unforeseen Consequences and Feedback Loops

# %% [markdown]
# ## Get Writing!

# %% [markdown]
# ## Questionnaire

# %% [markdown]
# 1. Provide an example of where the bear classification model might work poorly in production, due to structural or style differences in the training data.
# 1. Where do text models currently have a major deficiency?
# 1. What are possible negative societal implications of text generation models?
# 1. In situations where a model might make mistakes, and those mistakes could be harmful, what is a good alternative to automating a process?
# 1. What kind of tabular data is deep learning particularly good at?
# 1. What's a key downside of directly using a deep learning model for recommendation systems?
# 1. What are the steps of the Drivetrain Approach?
# 1. How do the steps of the Drivetrain Approach map to a recommendation system?
# 1. Create an image recognition model using data you curate, and deploy it on the web.
# 1. What is `DataLoaders`?
# 1. What four things do we need to tell fastai to create `DataLoaders`?
# 1. What does the `splitter` parameter to `DataBlock` do?
# 1. How do we ensure a random split always gives the same validation set?
# 1. What letters are often used to signify the independent and dependent variables?
# 1. What's the difference between the crop, pad, and squish resize approaches? When might you choose one over the others?
# 1. What is data augmentation? Why is it needed?
# 1. What is the difference between `item_tfms` and `batch_tfms`?
# 1. What is a confusion matrix?
# 1. What does `export` save?
# 1. What is it called when we use a model for getting predictions, instead of training?
# 1. What are IPython widgets?
# 1. When might you want to use CPU for deployment? When might GPU be better?
# 1. What are the downsides of deploying your app to a server, instead of to a client (or edge) device such as a phone or PC?
# 1. What are three examples of problems that could occur when rolling out a bear warning system in practice?
# 1. What is "out-of-domain data"?
# 1. What is "domain shift"?
# 1. What are the three steps in the deployment process?

# %% [markdown]
# ### Further Research

# %% [markdown]
# 1. Consider how the Drivetrain Approach maps to a project or problem you're interested in.
# 1. When might it be best to avoid certain types of data augmentation?
# 1. For a project you're interested in applying deep learning to, consider the thought experiment "What would happen if it went really, really well?"
# 1. Start a blog, and write your first blog post. For instance, write about what you think deep learning might be useful for in a domain you're interested in.
